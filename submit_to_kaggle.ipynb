# %% [markdown]
# <a href="https://colab.research.google.com/github/perseus98/ColabFILES/blob/master/submit_to_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle competitions submit -c titanic -f submission.csv -m "bla";
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 11, in <module>
#     load_entry_point('kaggle==1.5.3', 'console_scripts', 'kaggle')()
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 489, in load_entry_point
#     return get_distribution(dist).load_entry_point(group, name)
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 2793, in load_entry_point
#     return ep.load()
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 2411, in load
#     return self.resolve()
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 2417, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 116, in authenticate
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b7b99436-6e53-42fc-add3-2940d8dd5aa0" name="files[]" multiple disabled />
#      <output id="result-b7b99436-6e53-42fc-add3-2940d8dd5aa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# !ls
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !ls -l ~/.kaggle
# !cat ~/.kaggle/kaggle.json
# !cat kaggle.json

# %%
# !rm ~/.kaggle/kaggle.json

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2ec41b67-af63-4407-934c-6e4dd6797a7d" name="files[]" multiple disabled />
#      <output id="result-2ec41b67-af63-4407-934c-6e4dd6797a7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving out_titanic2.csv to out_titanic2.csv
# ...

# %%
# !kaggle competitions submit -c titanic -f gender_submission.csv -m "bla";
# ! kaggle competitions submit -c titanic -f gender_submission.csv -m "Message"
# ! kaggle competitions submit -c 'titanic' -f 'gender_submission.csv' -m 'ok'
! kaggle competitions submit -c titanic -f out_titanic2.csv -m 'ok'

# ! kaggle competitions download -c 'titanic'
# Out:
# 100% 3.18k/3.18k [00:01<00:00, 1.70kB/s]
# Successfully submitted to Titanic: Machine Learning from Disaster
