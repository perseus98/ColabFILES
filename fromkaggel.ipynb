# %% [markdown]
# <a href="https://colab.research.google.com/github/perseus98/ColabFILES/blob/master/fromkaggel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c20a1cf1-8029-4c03-96ae-5808c998ad70" name="files[]" multiple disabled />
#      <output id="result-c20a1cf1-8029-4c03-96ae-5808c998ad70">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"afrozml","key":"2a8e80110e6baf37c54e40a9e2e7ba6c"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !ls -l ~/.kaggle
# !cat ~/.kaggle/kaggle.json
# Out:
# total 4
# -rw------- 1 root root 63 Mar 28 11:48 kaggle.json
# {"username":"afrozml","key":"2a8e80110e6baf37c54e40a9e2e7ba6c"}

# %%
# !pip install -q kaggle
# !pip install -q kaggle-cli
# Out:
#     100% |████████████████████████████████| 81kB 5.2MB/s
#     100% |████████████████████████████████| 5.3MB 5.3MB/s
#     100% |████████████████████████████████| 92kB 27.8MB/s
#     100% |████████████████████████████████| 51kB 19.8MB/s
# ...

# %%
# !kaggle datasets list
# Out:
# ref                                                          title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# ronitf/heart-disease-uci                                     Heart Disease UCI                                     3KB  2018-06-25 11:33:56          20921
# jessicali9530/stanford-dogs-dataset                          Stanford Dogs Dataset                               735MB  2019-02-13 05:45:25           1776
# russellyates88/suicide-rates-overview-1985-to-2016           Suicide Rates Overview 1985 to 2016                 396KB  2018-12-01 19:18:25          15580
# lava18/google-play-store-apps                                Google Play Store Apps                                2MB  2019-02-03 13:55:47          45084
# ...

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2595           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      10535            True
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       4231            True
# imagenet-object-localization-challenge         2029-12-31 07:00:00  Research         Knowledge         36           False
# competitive-data-science-predict-future-sales  2019-12-31 23:59:00  Playground           Kudos       2618           False
# two-sigma-financial-news                       2019-07-15 23:59:00  Featured          $100,000       2927           False
# ...

# %%
# !kaggle competitions list -s diabetic
# Out:
# ref                             deadline             category    reward  teamCount  userHasEntered
# ------------------------------  -------------------  --------  --------  ---------  --------------
# diabetic-retinopathy-detection  2015-07-27 23:59:00  Featured  $100,000        661           False

# %%
! kaggle competitions download -c 'titanic'
# Out:
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 23.6MB/s]
# ...
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 26.8MB/s]
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 2.55MB/s]

# %%
ls
# Out:
# adc.json      gender_submission.csv  sample_data/  train.csv
# diabetes.csv  kaggle.json            test.csv

# %%
import pandas as pd

# %%
# !cd sample_data/

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
